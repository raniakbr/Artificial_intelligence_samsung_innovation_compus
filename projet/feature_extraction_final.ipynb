# %%
import PIL
from PIL import Image
import requests
from io import BytesIO
import webcolors
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy import misc, ndimage
from PIL import ImageEnhance
from imageai.Detection.Custom import CustomObjectDetection

#we are using our trained model from custom image detection in order to detection the objects 
detector = CustomObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(
    "./final_model/models/detection_model-ex-001--loss-0031.882.h5")
detector.setJsonPath("./final_model/json/detection_config.json")
detector.loadModel()

# %%
'''# rename the images 
#changez ça en fonction de vos répertoires
i=1
for f in listdir("./test"):
    if isfile(join("./test", f)) : 
        os.rename(join("./test", f), join("./test",str(i)+".jpg"))
        i+=1
'''

# %%
#closest_color  convert the RGB values to color_name
def closest_color(requested_colour):
    min_colours = {}
    for key, name in webcolors.CSS21_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

# %%
#returns the n  dominant colors
def top_colors(image, n):
    # convert the image to rgb
    image = image.convert('RGB')

    # resize the image to 300 x 300
    image = image.resize((300, 300))

    detected_colors = []
    for x in range(image.width):
        for y in range(image.height):
            detected_colors.append(closest_color(image.getpixel((x, y))))
    Series_Colors = pd.Series(detected_colors)
    output = Series_Colors.value_counts()/len(Series_Colors)
    return(output.head(n))

# %%
def merged_colors(color_list) : 
    for color,color_per in zip(color_list.index,color_list) : 
        if color == 'silver' : 
            try : 
                color_list['white'] += color_per
                color_list.drop(index=(color),inplace=True)
            except:
                color_list['white'] = color_per
                color_list.drop(index=(color), inplace=True)
        if color in ['olive','lime'] : 
            try : 
                color_list['green'] += color_per
                color_list.drop(index=(color), inplace=True)
            except : 
                color_list['green'] = color_per
                color_list.drop(index=(color), inplace=True)
        if color in ['aqua','teal','navy'] :
            try : 
                color_list['blue'] += color_per
                color_list.drop(index=(color), inplace=True)
            except :
                color_list['blue'] = color_per
                color_list.drop(index=(color), inplace=True)
        if color in ['maroon']:
            try : 
                color_list['red'] += color_per
                color_list.drop(index=(color), inplace=True)
            except:
                color_list['red'] = color_per
                color_list.drop(index=(color), inplace=True)
    return color_list

# %%
#returns the pourcentage of drawn area and its position
def exp_area(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    thresh = cv2.threshold(
        blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    x, y, w, h = cv2.boundingRect(thresh)
    return round((w*h)/(image.shape[0]*image.shape[1])*100, 2), round((x)/(image.shape[0])*100, 2), round((y)/(image.shape[1])*100, 2)

# %%
#returns the features of a drawing
def features(image) :
    print("traitement sur : "+image)
    img = Image.open(image)
    colors = merged_colors(top_colors(img, 6))
    print('Colors : ' ,colors)
    img = cv2.imread(image)
    area, x, y = exp_area(img)
    print('Exploited area : ' , area)
    position = [x, y]
    print('Position : ' , position)
    objects = detection(image)
    print('Objects : ', objects)
    return colors,position, area,objects

# %%
# returns the detected objects
def detection(image):
    output_image = '../'+image[0:-4]+'_rest.jpg'
    detections = detector.detectObjectsFromImage(
        input_image=image, output_image_path=output_image, minimum_percentage_probability=80)
    return list(map(lambda n: n['name'], detections))

# %%
#classify a drawing depending on its extracted features
def classifier(colors,position,exp_area,objects) : 
    if (exp_area < 30 and ((position[0] < 25 or position[0] > 75) and (position[1] < 25 or position[1] > 75))):
        print('Introversion and timidity')
        return 'Introversion and timidity'
    if 'purple' in colors.index and colors['purple'] > 0.25:
        print('Tension and emotional conflicts')
        return 'Tension and emotional conflicts'
    indice_p = 0
    for color in  colors.index : 
        if color in ['blue', 'green', 'yellow', 'Fuchsia'] and colors[color] > 0.01:
            
            indice_p += 1
    for object_ in objects : 
        if object_ in ['sun', 'rainbow']:
            indice_p += 1
    indice_n = 0 
    for color in colors.index:
        if color in ['red', 'black'] and colors[color] > 0.02:
            indice_n += 1
    for object_ in objects:
        if object_ in ['knife', 'rocket', 'hammer']:
            indice_n += 2
    if indice_n  > indice_p :
        print('Aggression and hostility')
        return ('Aggression and hostility')
    elif indice_n <= indice_p:
        print('Calm, peace and balance')
        return ('Calm, peace and balance')
    return print('Model failed to detect any emotional state')

# %%
#initialisation 
list_outputs = []
#list_white_parts = []
list_contours = []
list_exp_areas=[]
list_positions=[]
list_objects =[]
list_class_ = []
#récupère la listes de noms de fichier
list_images = [f for f in listdir("./test") if isfile(join("./test", f))]

# %%
#feature extraction for a list of drawings
for image in list_images:
    print("traitement sur : "+image)
    img = Image.open(join('./test/'+image))
    color = merged_colors(top_colors(img, 5))
    list_outputs.append(color)
    img = cv2.imread(join('./test/'+image))
    area, x, y = exp_area(img)
    position=[x,y]
    list_exp_areas.append(area)
    list_positions.append([x,y])
    objects = detection(join('./test/'+image))
    list_objects.append(objects)
    list_class_.append(classifier(color,position,area,objects))
# Out:
# traitement sur : 1.jpg
# [620, 61, 784, 234]
# [10, 354, 127, 547]
# Calm, peace and balance
# traitement sur : 10.jpg
# [21, 159, 88, 322]
# [23, 170, 86, 325]
# [313, 201, 382, 342]
# [165, 232, 246, 338]
# [158, 248, 267, 316]
# [313, 223, 375, 333]
# Calm, peace and balance
# traitement sur : 11.jpg
# [122, 348, 279, 635]
# Calm, peace and balance
# traitement sur : 12.jpg
# [219, 0, 551, 127]
# [0, 9, 272, 240]
# [337, 153, 493, 449]
# [474, 194, 666, 405]
# [80, 329, 204, 555]
# [80, 329, 204, 555]
# Calm, peace and balance
# traitement sur : 13.jpg
# [695, 0, 1021, 520]
# [130, 181, 385, 714]
# [863, 482, 1005, 836]
# [576, 675, 611, 725]
# [426, 757, 459, 845]
# Aggression and hostility
# traitement sur : 14.jpg
# [662, 177, 762, 883]
# [662, 177, 762, 883]
# [462, 312, 592, 827]
# [293, 464, 473, 865]
# [810, 372, 937, 953]
# Calm, peace and balance
# traitement sur : 15.jpg
# [201, 0, 337, 332]
# [13, 18, 155, 275]
# Calm, peace and balance
# traitement sur : 16.jpg
# [521, 0, 833, 293]
# [419, 12, 939, 273]
# [45, 66, 510, 776]
# [359, 333, 922, 719]
# Aggression and hostility
# traitement sur : 17.jpg
# [0, 159, 170, 354]
# [134, 116, 328, 558]
# [134, 116, 328, 558]
# [564, 121, 742, 553]
# Calm, peace and balance
# traitement sur : 18.jpg
# [155, 23, 226, 204]
# [23, 38, 98, 165]
# [278, 49, 337, 158]
# Aggression and hostility
# traitement sur : 19.jpg
# [33, 0, 269, 284]
# [33, 0, 269, 284]
# [262, 87, 554, 638]
# [518, 241, 688, 551]
# [828, 399, 930, 700]
# [78, 431, 192, 728]
# Calm, peace and balance
# traitement sur : 2.jpg
# [0, 0, 192, 393]
# [283, 15, 488, 354]
# [567, 0, 772, 403]
# Aggression and hostility
# traitement sur : 20.jpg
# [356, 68, 520, 325]
# [329, 124, 522, 287]
# [0, 241, 184, 358]
# Aggression and hostility
# traitement sur : 21.jpg
# [28, 44, 145, 160]
# [432, 38, 586, 171]
# [422, 184, 495, 310]
# [292, 186, 384, 333]
# [551, 191, 611, 323]
# Calm, peace and balance
# traitement sur : 22.jpg
# [0, 56, 269, 255]
# Introversion and timidity
# traitement sur : 23.jpg
# [70, 313, 211, 509]
# Aggression and hostility
# traitement sur : 24.jpg
# [231, 39, 427, 331]
# Aggression and hostility
# traitement sur : 25.jpg
# [98, 40, 164, 288]
# Aggression and hostility
# traitement sur : 26.jpg
# [21, 47, 88, 146]
# [168, 23, 210, 171]
# Aggression and hostility
# traitement sur : 27.jpg
# [79, 60, 114, 138]
# [79, 60, 114, 138]
# [157, 85, 200, 157]
# [218, 130, 257, 184]
# Calm, peace and balance
# traitement sur : 28.jpg
# [37, 8, 93, 55]
# [99, 67, 176, 185]
# [63, 105, 92, 182]
# [220, 96, 243, 190]
# [174, 115, 201, 187]
# Aggression and hostility
# traitement sur : 29.jpg
# [471, 0, 862, 247]
# [0, 73, 263, 431]
# [618, 228, 781, 557]
# [314, 250, 447, 572]
# [314, 250, 447, 572]
# [469, 374, 599, 574]
# Calm, peace and balance
# traitement sur : 3.jpg
# [54, 24, 577, 422]
# [54, 24, 577, 422]
# [526, 271, 742, 689]
# [826, 306, 1224, 670]
# [147, 389, 339, 673]
# [313, 361, 547, 721]
# Calm, peace and balance
# traitement sur : 30.jpg
# [129, 0, 204, 228]
# [222, 21, 283, 127]
# Calm, peace and balance
# traitement sur : 31.jpg
# [178, 48, 382, 499]
# [464, 72, 696, 494]
# Calm, peace and balance
# traitement sur : 32.jpg
# [9, 78, 65, 171]
# [92, 92, 139, 216]
# [142, 101, 215, 220]
# [228, 88, 258, 243]
# Calm, peace and balance
# traitement sur : 33.jpg
# [37, 18, 268, 287]
# Aggression and hostility
# traitement sur : 34.jpg
# [0, 42, 221, 181]
# [206, 212, 301, 447]
# [298, 197, 391, 454]
# [371, 245, 508, 443]
# Aggression and hostility
# traitement sur : 35.jpg
# [0, 89, 447, 547]
# [13, 401, 378, 1340]
# [578, 501, 874, 1251]
# Calm, peace and balance
# traitement sur : 36.jpg
# [22, 23, 184, 151]
# [22, 23, 184, 151]
# [124, 147, 289, 355]
# [5, 162, 137, 385]
# [423, 157, 538, 362]
# [561, 161, 655, 409]
# [10, 359, 140, 600]
# [491, 346, 814, 597]
# [491, 346, 814, 597]
# [113, 437, 270, 589]
# Calm, peace and balance
# traitement sur : 37.jpg
# [0, 0, 285, 327]
# [306, 36, 957, 232]
# [873, 0, 1345, 449]
# [791, 0, 1348, 478]
# [212, 247, 832, 708]
# [841, 673, 901, 777]
# Calm, peace and balance
# traitement sur : 38.jpg
# [22, 0, 126, 127]
# [675, 308, 773, 532]
# [18, 315, 96, 560]
# [685, 301, 762, 565]
# [228, 358, 350, 596]
# Aggression and hostility
# traitement sur : 39.jpg
# [230, 49, 272, 143]
# [233, 54, 267, 146]
# [58, 67, 101, 179]
# [50, 60, 108, 184]
# Aggression and hostility
# traitement sur : 4.jpg
# [32, 126, 230, 433]
# [166, 180, 327, 467]
# Calm, peace and balance
# traitement sur : 40.jpg
# [0, 7, 162, 189]
# [209, 182, 571, 450]
# [538, 244, 782, 522]
# Calm, peace and balance
# traitement sur : 41.jpg
# [818, 0, 1135, 932]
# [55, 69, 295, 906]
# [319, 150, 716, 955]
# Aggression and hostility
# traitement sur : 42.jpg
# [224, 108, 272, 168]
# [178, 119, 275, 178]
# [70, 129, 116, 185]
# Aggression and hostility
# traitement sur : 43.jpg
# [174, 0, 436, 582]
# Aggression and hostility
# traitement sur : 44.jpg
# [80, 136, 226, 254]
# [388, 189, 449, 373]
# [230, 213, 296, 377]
# Calm, peace and balance
# traitement sur : 45.jpg
# [96, 54, 192, 336]
# [296, 152, 660, 355]
# [327, 398, 369, 444]
# [423, 470, 454, 496]
# Calm, peace and balance
# traitement sur : 46.jpg
# [365, 66, 541, 206]
# [94, 218, 312, 463]
# [376, 256, 503, 427]
# Calm, peace and balance
# traitement sur : 47.jpg
# [341, 193, 424, 371]
# [438, 208, 521, 357]
# [441, 215, 517, 364]
# [182, 230, 247, 431]
# Calm, peace and balance
# traitement sur : 48.jpg
# [119, 41, 159, 142]
# [173, 33, 212, 150]
# [45, 75, 94, 133]
# Calm, peace and balance
# traitement sur : 49.jpg
# [46, 16, 336, 353]
# [0, 68, 449, 299]
# [678, 268, 856, 693]
# [678, 268, 856, 693]
# [1044, 524, 1188, 898]
# [83, 565, 256, 937]
# Calm, peace and balance
# traitement sur : 5.jpg
# [127, 92, 322, 563]
# [266, 0, 454, 162]
# [266, 0, 454, 162]
# [535, 108, 723, 494]
# [361, 318, 493, 503]
# [708, 318, 814, 608]
# Aggression and hostility
# traitement sur : 50.jpg
# [105, 0, 184, 115]
# [442, 0, 522, 135]
# [113, 150, 214, 313]
# [110, 170, 218, 312]
# [388, 293, 530, 392]
# [227, 194, 273, 350]
# Calm, peace and balance
# traitement sur : 51.jpg
# [497, 218, 641, 476]
# [672, 301, 777, 495]
# Calm, peace and balance
# traitement sur : 52.jpg
# [40, 24, 408, 308]
# [718, 6, 853, 97]
# Calm, peace and balance
# traitement sur : 53.jpg
# [0, 8, 206, 161]
# [162, 59, 440, 610]
# [482, 214, 856, 601]
# [345, 335, 485, 692]
# Calm, peace and balance
# traitement sur : 54.jpg
# [120, 261, 655, 490]
# Tension and emotional conflicts
# traitement sur : 55.jpg
# [176, 0, 498, 545]
# Calm, peace and balance
# traitement sur : 56.jpg
# [157, 115, 272, 291]
# [531, 203, 653, 437]
# [303, 243, 483, 435]
# Introversion and timidity
# traitement sur : 57.jpg
# [785, 43, 985, 374]
# [475, 52, 831, 473]
# [224, 221, 465, 432]
# [861, 372, 986, 664]
# [0, 510, 379, 737]
# Calm, peace and balance
# traitement sur : 58.jpg
# [16, 104, 266, 254]
# [223, 91, 477, 459]
# [440, 293, 500, 506]
# [642, 309, 727, 492]
# [521, 330, 597, 497]
# [27, 321, 108, 529]
# Calm, peace and balance
# traitement sur : 59.jpg
# [18, 0, 193, 185]
# [9, 7, 206, 136]
# [98, 187, 190, 447]
# [98, 187, 190, 447]
# [532, 276, 672, 410]
# [647, 265, 750, 463]
# [646, 267, 774, 459]
# Calm, peace and balance
# traitement sur : 6.jpg
# [378, 118, 662, 542]
# [636, 0, 769, 169]
# [95, 102, 301, 515]
# Aggression and hostility
# traitement sur : 60.jpg
# [611, 20, 797, 163]
# [394, 54, 560, 239]
# [24, 178, 236, 504]
# [583, 307, 694, 533]
# [689, 297, 769, 535]
# Aggression and hostility
# traitement sur : 7.jpg
# [379, 0, 547, 700]
# [282, 261, 347, 529]
# Aggression and hostility
# traitement sur : 8.jpg
# [219, 0, 551, 127]
# [0, 9, 272, 240]
# [337, 153, 493, 449]
# [474, 194, 666, 405]
# [80, 329, 204, 555]
# [80, 329, 204, 555]
# Calm, peace and balance
# traitement sur : 9.jpg
# [26, 26, 121, 148]
# [205, 53, 338, 350]
# [381, 112, 463, 291]
# Aggression and hostility

# %%
#putting the previous results on a dataframe
dict_images = {}
'''dict_images.update({"Image": list_images, "color": list_outputs,
                   "white_part": list_white_parts, "contour": list_contours,"exp_area":list_exp_areas , 'position' : list_positions})
'''
dict_images.update({"image": list_images, "color": list_outputs, 'position': list_positions,
                   "exp_area": list_exp_areas , 'objects' : list_objects,'class' : list_class_})

# %%
df = pd.DataFrame(dict_images)
df
# Out:
#      image                                              color       position  \
# 0    1.jpg  white     0.842422
# yellow    0.082278
# orange  ...     [3.0, 7.0]
# 1   10.jpg  white     0.865233
# gray      0.055433
# yellow  ...    [0.76, 4.2]
# 2   11.jpg  white    0.994867
# gray     0.001422
# green    0...  [22.6, 31.21]
# 3   12.jpg  white     0.706800
# gray      0.068756
# yellow  ...     [0.0, 0.0]
# 4   13.jpg  white     0.695678
# gray      0.158511
# orange  ...     [0.0, 0.0]
# 5   14.jpg  white     0.932867
# yellow    0.023789
# gray    ...    [0.0, 0.77]
# 6   15.jpg  gray     0.131911
# white    0.816144
# black    0...    [0.0, 0.98]
# 7   16.jpg  white    0.557367
# gray     0.224611
# black    0...     [0.0, 0.0]
# 8   17.jpg  white     0.961011
# orange    0.018811
# gray    ...  [1.85, 19.25]
# 9   18.jpg  white    0.898689
# gray     0.078489
# black    0...   [3.45, 1.86]
# 10  19.jpg  white     0.819256
# gray      0.086678
# yellow  ...   [1.43, 2.44]
# 11   2.jpg  white    0.950322
# gray     0.032233
# black    0...   [2.42, 1.86]
# 12  20.jpg  white    0.926278
# gray     0.051511
# red      0...    [0.0, 5.43]
# 13  21.jpg  white    0.855367
# gray     0.115067
# black    0...   [8.89, 4.22]
# 14  22.jpg  white    0.985733
# gray     0.014267
# dtype: flo...   [0.77, 3.82]
# 15  23.jpg  gray      0.973578
# black     0.025300
# purple  ...    [0.0, 8.25]
# 16  24.jpg  white    0.943444
# gray     0.039800
# black    0...  [52.72, 3.06]
# 17  25.jpg  gray     0.222589
# black    0.085667
# white    0...     [0.0, 0.0]
# 18  26.jpg  white     0.862589
# gray      0.109500
# purple  ...   [0.0, 13.86]
# 19  27.jpg  white     0.975678
# gray      0.022811
# purple  ...  [11.64, 4.87]
# 20  28.jpg  white     0.923867
# gray      0.057189
# yellow  ...   [6.32, 0.75]
# 21  29.jpg  white     0.936500
# gray      0.030944
# orange  ...     [0.0, 0.0]
# 22   3.jpg  white     0.877633
# gray      0.060133
# orange  ...    [0.0, 4.15]
# 23  30.jpg  white    0.864400
# gray     0.101533
# black    0...    [5.45, 0.0]
# 24  31.jpg  white    0.935511
# red      0.018767
# gray     0...  [21.38, 8.25]
# 25  32.jpg  white    0.844189
# gray     0.054933
# red      0...    [0.0, 7.29]
# 26  33.jpg  white    0.868700
# black    0.069233
# gray     0...     [0.0, 8.8]
# 27  34.jpg  white    0.878144
# gray     0.047433
# black    0...    [0.0, 0.75]
# 28  35.jpg  white    0.603689
# gray     0.072944
# green    0...     [0.0, 0.0]
# 29  36.jpg  white     0.803922
# gray      0.089900
# yellow  ...    [1.33, 2.5]
# 30  37.jpg  white     0.904256
# yellow    0.028711
# gray    ...    [0.0, 0.31]
# 31  38.jpg  white     0.873278
# yellow    0.061033
# orange  ...     [0.0, 0.0]
# 32  39.jpg  white     0.846289
# gray      0.101911
# yellow  ...     [0.0, 0.0]
# 33   4.jpg  white    0.714356
# gray     0.152356
# black    0...     [0.0, 0.0]
# 34  40.jpg  orange    0.200089
# yellow    0.045078
# gray    ...     [0.0, 0.0]
# 35  41.jpg  white     0.876111
# gray      0.051844
# orange  ...     [0.0, 2.0]
# 36  42.jpg  white    0.819389
# black    0.091022
# gray     0...     [0.0, 0.0]
# 37  43.jpg  white    0.714911
# black    0.147067
# gray     0...  [10.63, 2.12]
# 38  44.jpg  white    0.901733
# gray     0.096656
# black    0...    [4.1, 0.33]
# 39  45.jpg  white     0.818556
# gray      0.051433
# yellow  ...    [0.0, 7.25]
# 40  46.jpg  gray     0.689067
# green    0.035156
# white    0...     [0.0, 0.0]
# 41  47.jpg  white    0.926044
# gray     0.054156
# black    0...     [0.0, 0.0]
# 42  48.jpg  white     0.906589
# gray      0.050322
# yellow  ...  [17.74, 8.86]
# 43  49.jpg  white     0.830878
# gray      0.081967
# yellow  ...    [0.0, 2.38]
# 44   5.jpg  white     0.805611
# gray      0.056956
# orange  ...   [3.27, 4.88]
# 45  50.jpg  white    0.904622
# gray     0.087800
# black    0...     [0.0, 0.0]
# 46  51.jpg  white     0.822878
# gray      0.089478
# orange  ...    [0.0, 2.25]
# 47  52.jpg  gray     0.078578
# white    0.918889
# green    0...    [0.0, 0.23]
# 48  53.jpg  white    0.907111
# gray     0.043044
# black    0...    [2.9, 1.27]
# 49  54.jpg  purple    0.497367
# gray      0.087700
# white   ...     [0.0, 0.0]
# 50  55.jpg  white    0.732944
# gray     0.146311
# red      0...     [0.0, 0.0]
# 51  56.jpg  white    0.957789
# red      0.031967
# gray     0...  [24.27, 12.6]
# 52  57.jpg  white     0.739178
# gray      0.088678
# yellow  ...     [0.0, 0.0]
# 53  58.jpg  white     0.939456
# gray      0.024756
# orange  ...     [0.0, 5.0]
# 54  59.jpg  white     0.836778
# yellow    0.067956
# orange  ...    [0.0, 4.75]
# 55   6.jpg  white     0.879722
# gray      0.054589
# orange  ...     [0.0, 9.0]
# 56  60.jpg  white     0.896078
# gray      0.054800
# orange  ...    [0.0, 1.12]
# 57   7.jpg  white     0.765356
# purple    0.110078
# gray    ...    [0.0, 1.58]
# 58   8.jpg  white     0.706800
# gray      0.068756
# yellow  ...     [0.0, 0.0]
# 59   9.jpg  white    0.940744
# gray     0.055244
# black    0...    [6.28, 0.0]
#
#     exp_area                                            objects  \
# 0      84.89                                   [person, person]
# 1      91.96         [person, tree, person, person, tree, tree]
# 2       2.56                                           [person]
# 3     100.00        [sun, person, person, person, person, tree]
# 4      98.73           [person, rocket, person, flower, flower]
# 5      97.76             [person, tree, person, person, person]
# 6      96.14                                       [tree, tree]
# 7      97.57                       [person, sun, rocket, house]
# 8      56.90                       [person, person, tree, tree]
# 9      90.53                             [tree, rocket, person]
# 10     94.19      [knife, person, tree, person, person, person]
# 11     91.55                           [rocket, rocket, rocket]
# 12     80.99                               [tree, knife, knife]
# 13     83.25           [person, person, person, person, person]
# 14      6.44                                           [person]
# 15     89.00                                           [person]
# 16     21.86                                           [rocket]
# 17     99.69                                             [tree]
# 18     80.32                                   [rocket, rocket]
# 19     81.72                     [person, tree, person, person]
# 20     84.76           [person, person, person, rocket, person]
# 21    100.00        [person, house, tree, person, tree, person]
# 22     93.88       [person, sun, person, house, person, person]
# 23     96.25                                      [tree, house]
# 24     59.36                                       [tree, tree]
# 25     89.21                     [person, person, person, tree]
# 26     78.18                                            [knife]
# 27     94.82                     [person, person, tree, person]
# 28     98.49                                [house, tree, tree]
# 29     94.37  [knife, sun, house, person, person, person, pe...
# 30     98.31     [person, person, person, knife, house, flower]
# 31     99.88              [knife, person, person, tree, person]
# 32    100.00                     [rocket, person, tree, rocket]
# 33    100.00                                       [tree, tree]
# 34    100.00                            [person, house, person]
# 35     97.12                               [tree, rocket, tree]
# 36    100.00                            [person, house, person]
# 37     87.88                                            [house]
# 38     95.67                            [house, person, person]
# 39     89.26                    [person, house, flower, flower]
# 40    100.00                           [person, person, person]
# 41    100.00                     [person, person, tree, person]
# 42     57.77                           [person, person, person]
# 43     95.77        [person, sun, person, tree, person, person]
# 44     90.74        [tree, knife, person, tree, person, person]
# 45     99.66     [person, person, person, tree, person, person]
# 46     96.92                                   [person, person]
# 47     99.61                                    [house, person]
# 48     78.26                         [sun, tree, house, person]
# 49    100.00                                            [house]
# 50     93.46                                            [house]
# 51     29.23                            [knife, person, person]
# 52    100.00               [tree, tree, person, person, person]
# 53     93.58    [person, house, person, person, person, person]
# 54     92.76  [sun, person, person, tree, person, rocket, pe...
# 55     86.99                              [tree, house, rocket]
# 56     98.45           [person, person, rocket, person, person]
# 57     98.64                                    [knife, person]
# 58    100.00        [sun, person, person, person, person, tree]
# 59     84.96                           [person, rocket, person]
#
#                               class
# 0           Calm, peace and balance
# 1           Calm, peace and balance
# 2           Calm, peace and balance
# 3           Calm, peace and balance
# 4          Aggression and hostility
# 5           Calm, peace and balance
# 6           Calm, peace and balance
# 7          Aggression and hostility
# 8           Calm, peace and balance
# 9          Aggression and hostility
# 10          Calm, peace and balance
# 11         Aggression and hostility
# 12         Aggression and hostility
# 13          Calm, peace and balance
# 14        Introversion and timidity
# 15         Aggression and hostility
# 16         Aggression and hostility
# 17         Aggression and hostility
# 18         Aggression and hostility
# 19          Calm, peace and balance
# 20         Aggression and hostility
# 21          Calm, peace and balance
# 22          Calm, peace and balance
# 23          Calm, peace and balance
# 24          Calm, peace and balance
# 25          Calm, peace and balance
# 26         Aggression and hostility
# 27         Aggression and hostility
# 28          Calm, peace and balance
# 29          Calm, peace and balance
# 30          Calm, peace and balance
# 31         Aggression and hostility
# 32         Aggression and hostility
# 33          Calm, peace and balance
# 34          Calm, peace and balance
# 35         Aggression and hostility
# 36         Aggression and hostility
# 37         Aggression and hostility
# 38          Calm, peace and balance
# 39          Calm, peace and balance
# 40          Calm, peace and balance
# 41          Calm, peace and balance
# 42          Calm, peace and balance
# 43          Calm, peace and balance
# 44         Aggression and hostility
# 45          Calm, peace and balance
# 46          Calm, peace and balance
# 47          Calm, peace and balance
# 48          Calm, peace and balance
# 49  Tension and emotional conflicts
# 50          Calm, peace and balance
# 51        Introversion and timidity
# 52          Calm, peace and balance
# 53          Calm, peace and balance
# 54          Calm, peace and balance
# 55         Aggression and hostility
# 56         Aggression and hostility
# 57         Aggression and hostility
# 58          Calm, peace and balance
# 59         Aggression and hostility

# %%
#reading the csv file of the classified drawings (by the psychologist)
pd.read_csv('./images.csv')
# Out:
#      image                            class
# 0    1.jpg          Calm, peace and balance
# 1   10.jpg          Calm, peace and balance
# 2   11.jpg          Calm, peace and balance
# 3   12.jpg          Calm, peace and balance
# 4   13.jpg         Aggression and hostility
# 5   14.jpg          Calm, peace and balance
# 6   15.jpg          Calm, peace and balance
# 7   16.jpg          Calm, peace and balance
# 8   17.jpg          Calm, peace and balance
# 9   18.jpg         Aggression and hostility
# 10  19.jpg          Calm, peace and balance
# 11   2.jpg         Aggression and hostility
# 12  20.jpg         Aggression and hostility
# 13  21.jpg          Calm, peace and balance
# 14  22.jpg        Introversion and timidity
# 15  23.jpg         Aggression and hostility
# 16  24.jpg         Aggression and hostility
# 17  25.jpg         Aggression and hostility
# 18  26.jpg         Aggression and hostility
# 19  27.jpg          Calm, peace and balance
# 20  28.jpg         Aggression and hostility
# 21  29.jpg          Calm, peace and balance
# 22   3.jpg          Calm, peace and balance
# 23  30.jpg          Calm, peace and balance
# 24  31.jpg          Calm, peace and balance
# 25  32.jpg          Calm, peace and balance
# 26  33.jpg         Aggression and hostility
# 27  34.jpg         Aggression and hostility
# 28  35.jpg          Calm, peace and balance
# 29  36.jpg          Calm, peace and balance
# 30  37.jpg          Calm, peace and balance
# 31  38.jpg         Aggression and hostility
# 32  39.jpg         Aggression and hostility
# 33   4.jpg          Calm, peace and balance
# 34  40.jpg          Calm, peace and balance
# 35  41.jpg         Aggression and hostility
# 36  42.jpg         Aggression and hostility
# 37  43.jpg         Aggression and hostility
# 38  44.jpg          Calm, peace and balance
# 39  45.jpg          Calm, peace and balance
# 40  46.jpg          Calm, peace and balance
# 41  47.jpg          Calm, peace and balance
# 42  48.jpg          Calm, peace and balance
# 43  49.jpg          Calm, peace and balance
# 44   5.jpg          Calm, peace and balance
# 45  50.jpg          Calm, peace and balance
# 46  51.jpg          Calm, peace and balance
# 47  52.jpg          Calm, peace and balance
# 48  53.jpg          Calm, peace and balance
# 49  54.jpg  Tension and emotional conflicts
# 50  55.jpg          Calm, peace and balance
# 51  56.jpg        Introversion and timidity
# 52  57.jpg          Calm, peace and balance
# 53  58.jpg          Calm, peace and balance
# 54  59.jpg          Calm, peace and balance
# 55   6.jpg         Aggression and hostility
# 56  60.jpg         Aggression and hostility
# 57   7.jpg         Aggression and hostility
# 58   8.jpg          Calm, peace and balance
# 59   9.jpg         Aggression and hostility

# %%
compt=0
for (class1,class2) in zip(df_['class'],df['class']) : 
    if class1!= class2 :
        compt +=1
acc= (60-compt)/60

# %%
#print the accuracy 
acc
# Out:
# 0.9666666666666667
